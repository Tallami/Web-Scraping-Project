# %%
from scrapy.item import Field
from scrapy.item import Item
from scrapy.spiders import CrawlSpider, Rule
from scrapy.selector import Selector
from scrapy.loader.processors import MapCompose
from scrapy.linkextractors import LinkExtractor
from scrapy.loader import ItemLoader
from scrapy.crawler import CrawlerProcess
import os

# %%
class ProSetup(Item):
    name = Field()
    mouse = Field()
    sens = Field()
    dpi = Field()
    country = Field()

# %%
class ProSettings(CrawlSpider):
    name = 'ProSetups'
    custom_settings = {
        'USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36',
        'CLOSESPIDER_PAGECOUNT': 500,
        'FEED_EXPORT_ENCODING': 'utf-8',
        'FEED_EXPORT_FIELDS': ['name', 'country', 'mouse', 'dpi', 'sens'],
    }
    
    allowed_domains = ['prosettings.net']
    
    start_urls = ['https://prosettings.net/players/']
    
    download_delay = 1
    
    rules = (
        Rule(LinkExtractor(allow=r'/page/\d+/'), follow=True),
        Rule(LinkExtractor(allow=r'/players/', restrict_xpaths=[
             "//a[@class='js-link-target']"]), follow=True, callback='parse_player')
        )

    def parse_player(self, response):
        sel = Selector(response)
        item = ItemLoader(ProSetup(), sel)
        item.add_xpath('name', "//div[@class='name']//h1//text()")
        item.add_xpath('mouse', "//section[@class='settings-group section--mouse']//h4//text()")
        item.add_xpath('sens', "//tr[@data-field='sensitivity']//td//text()")
        item.add_xpath('dpi', "//tr[@data-field='dpi']//td//text()")
        item.add_xpath('country', "//span[@class='name']//text()")
        yield item.load_item()

# %%
output_path = os.path.join('data', 'raw', 'prosettings.csv')

process = CrawlerProcess({
    'FEED_FORMAT': 'csv',
    'FEED_URI': output_path
})
process.crawl(ProSettings)
process.start()
# Out:
# 2023-05-22 14:55:34 [scrapy.utils.log] INFO: Scrapy 2.9.0 started (bot: scrapybot)
# 2023-05-22 14:55:34 [scrapy.utils.log] INFO: Versions: lxml 4.9.2.0, libxml2 2.10.4, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.1, Twisted 22.10.0, Python 3.11.3 | packaged by conda-forge | (main, Apr  6 2023, 08:57:19) [GCC 11.3.0], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-5.10.16.3-microsoft-standard-WSL2-x86_64-with-glibc2.35
# 2023-05-22 14:55:34 [scrapy.crawler] INFO: Overridden settings:
# {'CLOSESPIDER_PAGECOUNT': 500,
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'FEED_EXPORT_FIELDS': ['name', 'country', 'mouse', 'dpi', 'sens'],
#  'USER_AGENT': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_1) '
#                'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 '
#                'Safari/537.36'}
# 2023-05-22 14:55:34 [py.warnings] WARNING: /home/tallami/mambaforge/envs/web-scraping/lib/python3.11/site-packages/scrapy/utils/request.py:232: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2023-05-22 14:55:34 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-05-22 14:55:35 [scrapy.extensions.telnet] INFO: Telnet Password: 46f3b1320633d5d3
# 2023-05-22 14:55:35 [py.warnings] WARNING: /home/tallami/mambaforge/envs/web-scraping/lib/python3.11/site-packages/scrapy/extensions/feedexport.py:326: ScrapyDeprecationWarning: The `FEED_URI` and `FEED_FORMAT` settings have been deprecated in favor of the `FEEDS` setting. Please see the `FEEDS` setting docs for more details
#   exporter = cls(crawler)
#
# 2023-05-22 14:55:35 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.closespider.CloseSpider',
#  'scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-22 14:55:35 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-22 14:55:35 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-22 14:55:35 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-22 14:55:35 [scrapy.core.engine] INFO: Spider opened
# 2023-05-22 14:55:35 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-22 14:55:35 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6025
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/> (referer: None)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/2/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/scream/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/yay/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/dev1ce/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/ml7/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/kennys/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/ropz/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/shroud/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/xantares/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/m0nesy/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/tenz/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/twistzz/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/b1t/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/s1mple/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/zywoo/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/niko/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/78/> (referer: https://prosettings.net/players/)
# 2023-05-22 14:55:35 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://prosettings.net/players/page/2/> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/scream/>
# {'country': ['Belgium'],
#  'dpi': ['400', '400'],
#  'mouse': ['Logitech G Pro X Superlight Black',
#            'Logitech G Pro X Superlight Black'],
#  'name': ['ScreaM'],
#  'sens': ['0.725', '2.5']}
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/mazino/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/alfajer/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/kephrii/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/d3ffo/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/paura/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/kyedae/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/b0i/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/yay/>
# {'country': ['United States'],
#  'dpi': ['800', '400'],
#  'mouse': ['Logitech G Pro X Superlight Black',
#            'Logitech G Pro X Superlight Black'],
#  'name': ['yay'],
#  'sens': ['0.27', '3.10']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/dev1ce/>
# {'country': ['Denmark'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['dev1ce'],
#  'sens': ['1.90']}
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/sirmaza/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/ml7/>
# {'country': ['Romania'],
#  'dpi': ['800'],
#  'mouse': ['Razer DeathAdder Essential'],
#  'name': ['mL7']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/kennys/>
# {'country': ['France'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['kennyS'],
#  'sens': ['2.2']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/ropz/>
# {'country': ['Estonia'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-CW'],
#  'name': ['ropz'],
#  'sens': ['1.77']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/shroud/>
# {'country': ['Canada'],
#  'dpi': ['400', '400', '400', '400', '400', '400', '400'],
#  'mouse': ['Logitech G303 Shroud Edition',
#            'Logitech G303 Shroud Edition',
#            'Logitech G303 Shroud Edition',
#            'Logitech G303 Shroud Edition',
#            'Logitech G303 Shroud Edition',
#            'Logitech G303 Shroud Edition',
#            'Logitech G303 Shroud Edition'],
#  'name': ['shroud'],
#  'sens': ['2.4', '0.77', '3', '7.5']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/xantares/>
# {'country': ['Turkey'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE FK1-C'],
#  'name': ['XANTARES'],
#  'sens': ['2']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/m0nesy/>
# {'country': ['Russia'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['m0NESY'],
#  'sens': ['2']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/tenz/>
# {'country': ['Canada'],
#  'dpi': ['1600', '1600'],
#  'mouse': ['Logitech G Pro X Superlight Black',
#            'Logitech G Pro X Superlight Black'],
#  'name': ['TenZ'],
#  'sens': ['0.2', '0.477']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/twistzz/>
# {'country': ['Canada'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight White'],
#  'name': ['Twistzz'],
#  'sens': ['1.7']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/b1t/>
# {'country': ['Ukraine'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['b1t'],
#  'sens': ['1.42']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/s1mple/>
# {'country': ['Ukraine'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight White'],
#  'name': ['s1mple'],
#  'sens': ['3.09']}
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/zywoo/>
# {'country': ['France'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-CW'],
#  'name': ['ZywOo'],
#  'sens': ['2']}
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/leo/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/enzo/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/aunkere/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/yekindar/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/mistic/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/l1nk/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/electronic/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:35 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/niko/>
# {'country': ['Bosnia & Herzegovina'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE XE Wireless Black'],
#  'name': ['NiKo'],
#  'sens': ['1.52']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/3/> (referer: https://prosettings.net/players/page/2/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/mazino/>
# {'country': ['Chile'],
#  'dpi': ['1600'],
#  'mouse': ['Logitech G703'],
#  'name': ['Mazino'],
#  'sens': ['0.15']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/alfajer/>
# {'country': ['Turkey'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight White'],
#  'name': ['Alfajer'],
#  'sens': ['0.45']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/kephrii/>
# {'country': ['United States'],
#  'dpi': ['400'],
#  'mouse': ['ASUS ROG Gladius'],
#  'name': ['Kephrii']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/d3ffo/>
# {'country': ['Russia'],
#  'dpi': ['800'],
#  'mouse': ['VAXEE ZYGEN NP-01'],
#  'name': ['d3ffo'],
#  'sens': ['0.51']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/paura/>
# {'country': ['Turkey'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE S2'],
#  'name': ['pAura'],
#  'sens': ['0.55']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/kyedae/>
# {'country': ['Canada'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight White'],
#  'name': ['Kyedae'],
#  'sens': ['0.44']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/b0i/>
# {'country': ['United States'],
#  'dpi': ['1600'],
#  'mouse': ['Logitech G303 Shroud Edition'],
#  'name': ['b0i'],
#  'sens': ['0.47']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/sirmaza/>
# {'country': ['Spain'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['SirMaza'],
#  'sens': ['0.5']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/spinx/> (referer: https://prosettings.net/players/zywoo/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/dupreeh/> (referer: https://prosettings.net/players/zywoo/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/magisk/> (referer: https://prosettings.net/players/zywoo/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/perfecto/> (referer: https://prosettings.net/players/b1t/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/npl/> (referer: https://prosettings.net/players/b1t/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/zekken/> (referer: https://prosettings.net/players/tenz/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/sacy/> (referer: https://prosettings.net/players/tenz/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/leo/>
# {'country': ['Sweden'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro White'],
#  'name': ['Leo'],
#  'sens': ['0.41']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/enzo/>
# {'country': ['France'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Enzo'],
#  'sens': ['0.5']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/aunkere/>
# {'country': ['Russia'],
#  'dpi': ['500'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Aunkere'],
#  'sens': ['2.1']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/pancada/> (referer: https://prosettings.net/players/tenz/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/yekindar/>
# {'country': ['Latvia'],
#  'dpi': ['800'],
#  'mouse': ['ZOWIE EC2-CW'],
#  'name': ['YEKINDAR'],
#  'sens': ['1.2']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/mistic/>
# {'country': ['United Kingdom'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE ZYGEN NP-01'],
#  'name': ['Mistic'],
#  'sens': ['0.58']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/l1nk/>
# {'country': ['United Kingdom'],
#  'dpi': ['800'],
#  'mouse': ['VAXEE XE Wireless Black'],
#  'name': ['L1NK'],
#  'sens': ['0.24']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/electronic/>
# {'country': ['Russia'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-CW'],
#  'name': ['electronic'],
#  'sens': ['2.2']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/jks/> (referer: https://prosettings.net/players/m0nesy/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/hunter/> (referer: https://prosettings.net/players/m0nesy/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/hooxi/> (referer: https://prosettings.net/players/m0nesy/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/wicadia/> (referer: https://prosettings.net/players/xantares/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/xfl0ud/> (referer: https://prosettings.net/players/xantares/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/calyx/> (referer: https://prosettings.net/players/xantares/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/woxic/> (referer: https://prosettings.net/players/xantares/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/spinx/>
# {'country': ['Israel'],
#  'dpi': ['900'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['Spinx'],
#  'sens': ['1.1']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/dupreeh/>
# {'country': ['Denmark'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-CW'],
#  'name': ['dupreeh'],
#  'sens': ['1.7']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/magisk/>
# {'country': ['Denmark'],
#  'dpi': ['800'],
#  'mouse': ['Razer Deathadder V3 Pro White'],
#  'name': ['Magisk'],
#  'sens': ['1']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/perfecto/>
# {'country': ['Russia'],
#  'dpi': ['800'],
#  'mouse': ['VAXEE XE Wireless Pink'],
#  'name': ['Perfecto'],
#  'sens': ['1']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/npl/>
# {'country': ['Ukraine'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['npl'],
#  'sens': ['1.55']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/keloqz/> (referer: https://prosettings.net/players/sirmaza/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/zekken/>
# {'country': ['United States'],
#  'dpi': ['1600'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Zekken'],
#  'sens': ['0.175']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/sacy/>
# {'country': ['Brazil'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['Sacy'],
#  'sens': ['0.425']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/pancada/>
# {'country': ['Brazil'],
#  'dpi': ['800'],
#  'mouse': ['ZOWIE EC2-CW'],
#  'name': ['pANcada'],
#  'sens': ['0.28']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/boo/> (referer: https://prosettings.net/players/sirmaza/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/mixwell/> (referer: https://prosettings.net/players/sirmaza/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/zeek/> (referer: https://prosettings.net/players/sirmaza/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/avova/> (referer: https://prosettings.net/players/sirmaza/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/garnets/> (referer: https://prosettings.net/players/b0i/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/jitboys/> (referer: https://prosettings.net/players/b0i/)
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/patiphan/> (referer: https://prosettings.net/players/b0i/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/jks/>
# {'country': ['Australia'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro White'],
#  'name': ['jks'],
#  'sens': ['1.7']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/hunter/>
# {'country': ['Bosnia & Herzegovina'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['huNter'],
#  'sens': ['2.17']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/hooxi/>
# {'country': ['Denmark'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['HooXi'],
#  'sens': ['2.5']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/wicadia/>
# {'country': ['Turkey'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Wicadia'],
#  'sens': ['1.7']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/xfl0ud/>
# {'country': ['Turkey'],
#  'dpi': ['800'],
#  'mouse': ['ZOWIE EC3-CW'],
#  'name': ['xfl0ud'],
#  'sens': ['1.3']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/calyx/>
# {'country': ['Turkey'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['Calyx'],
#  'sens': ['1.30']}
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/woxic/>
# {'country': ['Turkey'],
#  'dpi': ['1620'],
#  'mouse': ['SteelSeries Sensei Ten'],
#  'name': ['woxic'],
#  'sens': ['1.5']}
# 2023-05-22 14:55:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/magnum/> (referer: https://prosettings.net/players/mistic/)
# 2023-05-22 14:55:36 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/keloqz/>
# {'country': ['France'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['keloqz'],
#  'sens': ['0.44']}
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/phaze/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/victor/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/rogue/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/aqua/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/tayson/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/mrsavage/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/sommerset/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/boo/>
# {'country': ['Lithuania'],
#  'dpi': ['400'],
#  'mouse': ['Razer Viper V2 Pro Black'],
#  'name': ['Boo'],
#  'sens': ['0.75']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/mixwell/>
# {'country': ['Spain'],
#  'dpi': ['400', '400'],
#  'mouse': ['Logitech G703', 'Logitech G703'],
#  'name': ['mixwell'],
#  'sens': ['0.69', '2.20']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/zeek/>
# {'country': ['Poland'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['Zeek'],
#  'sens': ['0.37']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/avova/>
# {'country': ['Denmark'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['AvovA'],
#  'sens': ['0.333']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/garnets/>
# {'country': ['Thailand'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['garnetS'],
#  'sens': ['0.86']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/jitboys/>
# {'country': ['Thailand'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['JitBoyS'],
#  'sens': ['0.35']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/patiphan/>
# {'country': ['Thailand'],
#  'dpi': ['800', '800'],
#  'mouse': ['Endgame Gear XM1R', 'Endgame Gear XM1R'],
#  'name': ['Patiphan'],
#  'sens': ['0.7']}
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/kenzo/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/magnum/>
# {'country': ['Czechia'],
#  'dpi': ['400'],
#  'mouse': ['Razer Viper V2 Pro Black'],
#  'name': ['Magnum'],
#  'sens': ['0.454']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/phaze/>
# {'country': ['Egypt'],
#  'dpi': ['800'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['phaze'],
#  'sens': ['0.4']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/victor/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Victor'],
#  'sens': ['0.283']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/rogue/>
# {'country': ['Canada'],
#  'dpi': ['400'],
#  'mouse': ['FinalMouse Starlight-12'],
#  'name': ['Rogue'],
#  'sens': ['2.5']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/aqua/>
# {'country': ['Austria'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['aqua']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/tayson/>
# {'country': ['Slovenia'],
#  'dpi': ['1600'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['TaySon']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/mrsavage/>
# {'country': ['Norway'],
#  'dpi': ['800'],
#  'mouse': ['Roccat Kone Pro Air'],
#  'name': ['MrSavage']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/sommerset/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['Sommerset']}
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nitr0/> (referer: https://prosettings.net/players/yekindar/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/4/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/sscary/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/ops/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/shao/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/melser/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/epikwhale/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/toose/> (referer: https://prosettings.net/players/page/3/)
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/kenzo/>
# {'country': ['Sweden'],
#  'dpi': ['800'],
#  'mouse': ['Glorious Model O- Wireless'],
#  'name': ['Kenzo']}
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/crws/> (referer: https://prosettings.net/players/b0i/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/osee/> (referer: https://prosettings.net/players/yekindar/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/stellar/> (referer: https://prosettings.net/players/kyedae/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/naf/> (referer: https://prosettings.net/players/yekindar/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/sushiboys/> (referer: https://prosettings.net/players/b0i/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/bang/> (referer: https://prosettings.net/players/kyedae/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/asuna/> (referer: https://prosettings.net/players/kyedae/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/elige/> (referer: https://prosettings.net/players/yekindar/)
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/nitr0/>
# {'country': ['United States'],
#  'dpi': ['400', '400'],
#  'mouse': ['VAXEE XE Wireless Blue', 'VAXEE XE Wireless Blue'],
#  'name': ['nitr0'],
#  'sens': ['1.8', '0.7']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/sscary/>
# {'country': ['Thailand'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['sScary'],
#  'sens': ['0.36']}
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/endretta/> (referer: https://prosettings.net/players/mrsavage/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/andilex/> (referer: https://prosettings.net/players/tayson/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/ardiis/> (referer: https://prosettings.net/players/victor/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/falltw/> (referer: https://prosettings.net/players/phaze/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/derrek/> (referer: https://prosettings.net/players/kyedae/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/boaster/> (referer: https://prosettings.net/players/alfajer/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/derke/> (referer: https://prosettings.net/players/alfajer/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/chronicle/> (referer: https://prosettings.net/players/alfajer/)
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/ops/>
# {'country': ['United States'],
#  'dpi': ['1500'],
#  'mouse': ['Logitech G Pro Wireless'],
#  'name': ['ops']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/shao/>
# {'country': ['Russia'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['Shao'],
#  'sens': ['0.428']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/melser/>
# {'country': ['Chile'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['Melser'],
#  'sens': ['0.56']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/epikwhale/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro Wireless'],
#  'name': ['EpikWhale']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/toose/>
# {'country': ['Russia'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G305'],
#  'name': ['Toose']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/crws/>
# {'country': ['Thailand'],
#  'dpi': ['1600'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['Crws'],
#  'sens': ['0.15']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/osee/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Razer Viper Mini Signature Edition'],
#  'name': ['oSee'],
#  'sens': ['0.85']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/stellar/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight White'],
#  'name': ['stellar'],
#  'sens': ['0.3']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/naf/>
# {'country': ['Canada'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE XE Orange'],
#  'name': ['NAF'],
#  'sens': ['1.60']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/sushiboys/>
# {'country': ['Thailand'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Magenta'],
#  'name': ['sushiboys'],
#  'sens': ['0.37']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/bang/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['bang'],
#  'sens': ['0.32']}
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/asuna/>
# {'country': ['United States'],
#  'dpi': ['1400'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['Asuna'],
#  'sens': ['0.272']}
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nyhrox/> (referer: https://prosettings.net/players/mrsavage/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/s0m/> (referer: https://prosettings.net/players/victor/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/fns/> (referer: https://prosettings.net/players/victor/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/crashies/> (referer: https://prosettings.net/players/victor/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/shniider/> (referer: https://prosettings.net/players/phaze/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/kingg/> (referer: https://prosettings.net/players/mazino/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/tacolilla/> (referer: https://prosettings.net/players/mazino/)
# 2023-05-22 14:55:37 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/shyy/> (referer: https://prosettings.net/players/mazino/)
# 2023-05-22 14:55:37 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/elige/>
# {'country': ['United States'],
#  'dpi': ['1600'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['EliGE'],
#  'sens': ['0.74']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/endretta/>
# {'country': ['Norway'],
#  'dpi': ['400'],
#  'mouse': ['Razer Viper Mini'],
#  'name': ['Endretta']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/andilex/>
# {'country': ['France'],
#  'dpi': ['700'],
#  'mouse': ['Razer Viper V2 Pro Black'],
#  'name': ['Andilex']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/ardiis/>
# {'country': ['Latvia'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['ardiis'],
#  'sens': ['0.27']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/falltw/>
# {'country': ['Russia'],
#  'dpi': ['800'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['falltw'],
#  'sens': ['0.377']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/derrek/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['derrek'],
#  'sens': ['0.375']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/boaster/>
# {'country': ['United Kingdom'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight White'],
#  'name': ['Boaster'],
#  'sens': ['0.52']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/derke/>
# {'country': ['Finland'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Derke'],
#  'sens': ['0.74']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/chronicle/>
# {'country': ['Russia'],
#  'dpi': ['800'],
#  'mouse': ['VAXEE XE Wireless Yellow'],
#  'name': ['Chronicle'],
#  'sens': ['0.25']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/nyhrox/>
# {'country': ['Norway'],
#  'dpi': ['800'],
#  'mouse': ['FinalMouse Air58 Ninja CBR'],
#  'name': ['nyhrox']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/s0m/>
# {'country': ['United States'],
#  'dpi': ['400', '400'],
#  'mouse': ['Logitech G Pro X Superlight Red',
#            'Logitech G Pro X Superlight Red'],
#  'name': ['s0m'],
#  'sens': ['0.8', '2.35']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/fns/>
# {'country': ['Canada'],
#  'dpi': ['400', '400'],
#  'mouse': ['Logitech G Pro Wireless', 'Logitech G Pro Wireless'],
#  'name': ['FNS'],
#  'sens': ['0.55', '1.75']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/crashies/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro Wireless'],
#  'name': ['crashies'],
#  'sens': ['0.25']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/shniider/>
# {'country': ['Egypt'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['Shniider'],
#  'sens': ['0.6']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/kingg/>
# {'country': ['Chile'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['kiNgg'],
#  'sens': ['0.27']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/tacolilla/>
# {'country': ['Chile'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Tacolilla'],
#  'sens': ['0.3']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/shyy/>
# {'country': ['Chile'],
#  'dpi': ['800'],
#  'mouse': ['Razer Viper V2 Pro Black'],
#  'name': ['Shyy'],
#  'sens': ['0.32']}
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/snacky/> (referer: https://prosettings.net/players/epikwhale/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/klaus/> (referer: https://prosettings.net/players/melser/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/keznit/> (referer: https://prosettings.net/players/melser/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/ange1/> (referer: https://prosettings.net/players/shao/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/cned/> (referer: https://prosettings.net/players/shao/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/zyppan/> (referer: https://prosettings.net/players/shao/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/letw1k3/> (referer: https://prosettings.net/players/toose/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/reet/> (referer: https://prosettings.net/players/epikwhale/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/lyr1c/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/mwzera/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/suygetsu/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/c0m/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nagzet/> (referer: https://prosettings.net/players/melser/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/xdll/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/trent/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/bcj/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/5/> (referer: https://prosettings.net/players/page/4/)
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/snacky/>
# {'country': ['Mexico'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Snacky']}
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/russ-turkey/> (referer: https://prosettings.net/players/paura/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/foxz/> (referer: https://prosettings.net/players/b0i/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/pyth/> (referer: https://prosettings.net/players/sscary/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/swagg/> (referer: https://prosettings.net/players/page/78/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/cryocells/> (referer: https://prosettings.net/players/kyedae/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nozwerr/> (referer: https://prosettings.net/players/mazino/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/kalios/> (referer: https://prosettings.net/players/page/78/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/ado/> (referer: https://prosettings.net/players/page/78/)
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/klaus/>
# {'country': ['Argentina'],
#  'dpi': ['800'],
#  'mouse': ['Razer Viper V2 Pro Black'],
#  'name': ['Klaus'],
#  'sens': ['0.5']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/keznit/>
# {'country': ['Chile'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['keznit'],
#  'sens': ['0.346']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/ange1/>
# {'country': ['Ukraine'],
#  'dpi': ['800', '400'],
#  'mouse': ['Razer Deathadder V3 Pro White', 'Razer Deathadder V3 Pro White'],
#  'name': ['ANGE1'],
#  'sens': ['0.5', '1.70']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/cned/>
# {'country': ['Turkey'],
#  'dpi': ['800'],
#  'mouse': ['VAXEE XE Wireless Blue'],
#  'name': ['cNed'],
#  'sens': ['0.32']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/zyppan/>
# {'country': ['Sweden'],
#  'dpi': ['800'],
#  'mouse': ['VAXEE XE Wireless Orange'],
#  'name': ['Zyppan'],
#  'sens': ['0.3']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/letw1k3/>
# {'country': ['Russia'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['letw1k3']}
# 2023-05-22 14:55:38 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/reet/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro Wireless'],
#  'name': ['Reet']}
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/karonpe/> (referer: https://prosettings.net/players/page/78/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/advent/> (referer: https://prosettings.net/players/page/78/)
# 2023-05-22 14:55:38 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/sellter/> (referer: https://prosettings.net/players/page/78/)
# ...
#  'name': ['DD'],
#  'sens': ['2.40']}
# 2023-05-22 14:55:56 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/sharpshot/>
# {'country': ['Cuba'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Sharpshot']}
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/fox/> (referer: https://prosettings.net/players/page/10/)
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/maty/> (referer: https://prosettings.net/players/page/10/)
# 2023-05-22 14:55:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/fox/>
# {'country': ['Portugal'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE XE Wireless Blue'],
#  'name': ['fox'],
#  'sens': ['4.70']}
# 2023-05-22 14:55:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/maty/>
# {'country': ['Lithuania'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-B Divina Pink'],
#  'name': ['maty'],
#  'sens': ['1.7']}
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/leo_drk/> (referer: https://prosettings.net/players/steel-brazil/)
# 2023-05-22 14:55:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/leo_drk/>
# {'country': ['Brazil'],
#  'dpi': ['400'],
#  'mouse': ['Pulsar Xlite Wireless'],
#  'name': ['leo_drk'],
#  'sens': ['1.40']}
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nodios/> (referer: https://prosettings.net/players/lucky-danish/)
# 2023-05-22 14:55:57 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/nodios/>
# {'country': ['Denmark'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC1-A'],
#  'name': ['Nodios'],
#  'sens': ['1.51']}
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/autimatic/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/braexco/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/duckmanz/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:55:57 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/rush/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nourinz/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/autimatic/>
# {'country': ['United States'],
#  'dpi': ['400', '400'],
#  'mouse': ['Logitech G Pro X Superlight White',
#            'Logitech G Pro X Superlight White'],
#  'name': ['autimatic'],
#  'sens': ['2.024', '0.707']}
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/conaxy/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/braexco/>
# {'country': ['Germany'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Braexco']}
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/duckmanz/>
# {'country': ['Thailand'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE FK2'],
#  'name': ['DUCKMANZ']}
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/jeorge/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/rush/>
# {'country': ['United States'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['RUSH'],
#  'sens': ['2.4']}
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/nourinz/>
# {'country': ['Thailand'],
#  'dpi': ['400'],
#  'mouse': ['FinalMouse Starlight-12'],
#  'name': ['Nourinz']}
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/conaxy/>
# {'country': ['Thailand'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G203'],
#  'name': ['Conaxy']}
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/jeorge/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Jeorge'],
#  'sens': ['1.55']}
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/refrezh/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/refrezh/>
# {'country': ['Denmark'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['refrezh'],
#  'sens': ['1.90']}
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/hext/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/hext/>
# {'country': ['Canada'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro White'],
#  'name': ['HexT'],
#  'sens': ['1.4']}
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/wiz/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/junior/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:55:58 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/wiz/>
# {'country': ['United States'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['wiz'],
#  'sens': ['1.2']}
# 2023-05-22 14:55:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/junior/>
# {'country': ['United States'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro White'],
#  'name': ['junior'],
#  'sens': ['3.1']}
# 2023-05-22 14:55:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/speed4k/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:55:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/speed4k/>
# {'country': ['Russia'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['speed4k'],
#  'sens': ['2.00']}
# 2023-05-22 14:55:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/redstar/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:55:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/redstar/>
# {'country': ['Bulgaria'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE ZYGEN NP-01S Glossy'],
#  'name': ['REDSTAR'],
#  'sens': ['2.00']}
# 2023-05-22 14:55:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/v1c7or/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:55:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/v1c7or/>
# {'country': ['Bulgaria'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['v1c7oR'],
#  'sens': ['0.64']}
# 2023-05-22 14:55:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/meyern/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:55:59 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/allu/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:55:59 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/meyern/>
# {'country': ['Argentina'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['meyern'],
#  'sens': ['2.50']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/allu/>
# {'country': ['Finland'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['allu'],
#  'sens': ['3.00']}
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/brehze/> (referer: https://prosettings.net/players/walco/)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/h4rn/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/vanity/> (referer: https://prosettings.net/players/v1c/)
# 2023-05-22 14:56:00 [scrapy.core.engine] INFO: Closing spider (closespider_pagecount)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/moose/> (referer: https://prosettings.net/players/v1c/)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/jdc/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/brehze/>
# {'country': ['United States'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-C'],
#  'name': ['Brehze'],
#  'sens': ['3']}
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/eaddy/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/noardra/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/h4rn/>
# {'country': ['Bulgaria'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE ZYGEN NP-01'],
#  'name': ['h4rn'],
#  'sens': ['2.05']}
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/68/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/longskr/> (referer: https://prosettings.net/players/page/69/)
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/vanity/>
# {'country': ['United States'],
#  'dpi': ['1600', '800'],
#  'mouse': ['ZOWIE EC2-CW', 'ZOWIE EC2-CW'],
#  'name': ['vanity'],
#  'sens': ['0.141', '1.05']}
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/striker/> (referer: https://prosettings.net/players/smurf/)
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/moose/>
# {'country': ['Canada'],
#  'dpi': ['800', '400'],
#  'mouse': ['Razer Deathadder V3 Pro White', 'Razer Deathadder V3 Pro White'],
#  'name': ['Moose'],
#  'sens': ['0.33', '1.9']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/jdc/>
# {'country': ['Germany'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Red'],
#  'name': ['JDC'],
#  'sens': ['2.10']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/eaddy/>
# {'country': ['Thailand'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro Wireless'],
#  'name': ['Eaddy']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/noardra/>
# {'country': ['Thailand'],
#  'dpi': ['800'],
#  'mouse': ['FinalMouse Starlight-12'],
#  'name': ['Noardra']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/longskr/>
# {'country': ['China'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE FK1-B'],
#  'name': ['LongSkr']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/striker/>
# {'country': ['South Korea'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Striker']}
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/stanislaw/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/nifty/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/stanislaw/>
# {'country': ['Canada'],
#  'dpi': ['400'],
#  'mouse': ['Razer Viper Ultimate'],
#  'name': ['stanislaw'],
#  'sens': ['2.50']}
# 2023-05-22 14:56:00 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/nifty/>
# {'country': ['United States'],
#  'dpi': ['400'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Nifty'],
#  'sens': ['2.20']}
# 2023-05-22 14:56:00 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/malta/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/malta/>
# {'country': ['Australia'],
#  'dpi': ['400'],
#  'mouse': ['ZOWIE EC2-B Divina Pink'],
#  'name': ['malta'],
#  'sens': ['2.00']}
# 2023-05-22 14:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/tenzki/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/tenzki/>
# {'country': ['Denmark'],
#  'dpi': ['400'],
#  'mouse': ['Razer Deathadder V3 Pro Black'],
#  'name': ['tenzki'],
#  'sens': ['1.80']}
# 2023-05-22 14:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/page/12/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/zoree/> (referer: https://prosettings.net/players/allu/)
# 2023-05-22 14:56:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/maniac/> (referer: https://prosettings.net/players/page/11/)
# 2023-05-22 14:56:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/zoree/>
# {'country': ['Finland'],
#  'dpi': ['400'],
#  'mouse': ['Zowie S1 Divina Pink'],
#  'name': ['ZOREE'],
#  'sens': ['2.00']}
# 2023-05-22 14:56:01 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/maniac/>
# {'country': ['Switzerland'],
#  'dpi': ['800'],
#  'mouse': ['Logitech G Pro X Superlight Black'],
#  'name': ['Maniac'],
#  'sens': ['1.05']}
# 2023-05-22 14:56:02 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://prosettings.net/players/slowi/> (referer: https://prosettings.net/players/allu/)
# 2023-05-22 14:56:02 [scrapy.core.scraper] DEBUG: Scraped from <200 https://prosettings.net/players/slowi/>
# {'country': ['Finland'],
#  'dpi': ['400'],
#  'mouse': ['VAXEE OUTSET AX'],
#  'name': ['sLowi'],
#  'sens': ['3.20']}
# 2023-05-22 14:56:02 [scrapy.extensions.feedexport] INFO: Stored csv feed (492 items) in: data/raw/prosettings.csv
# 2023-05-22 14:56:02 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 271032,
#  'downloader/request_count': 515,
#  'downloader/request_method_count/GET': 515,
#  'downloader/response_bytes': 21587965,
#  'downloader/response_count': 515,
#  'downloader/response_status_count/200': 515,
#  'dupefilter/filtered': 1331,
#  'elapsed_time_seconds': 27.199441,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'closespider_pagecount',
#  'finish_time': datetime.datetime(2023, 5, 22, 17, 56, 2, 346408),
#  'httpcompression/response_bytes': 126680128,
#  'httpcompression/response_count': 515,
#  'item_scraped_count': 492,
#  'log_count/DEBUG': 1009,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 2,
#  'memusage/max': 155881472,
#  'memusage/startup': 155881472,
#  'request_depth_max': 13,
#  'response_received_count': 515,
#  'scheduler/dequeued': 515,
#  'scheduler/dequeued/memory': 515,
#  'scheduler/enqueued': 548,
#  'scheduler/enqueued/memory': 548,
#  'start_time': datetime.datetime(2023, 5, 22, 17, 55, 35, 146967)}
# 2023-05-22 14:56:02 [scrapy.core.engine] INFO: Spider closed (closespider_pagecount)
